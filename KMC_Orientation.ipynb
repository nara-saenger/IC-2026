# %%
import random 
import math
import matplotlib.pyplot as plt
import numpy as np
import json
from scipy.optimize import curve_fit

# %%
# Carregar a rede 


#Função

def rede(N):
    lista = []
    for i in range(int(N)):
        pi = np.pi
        teta = np.random.uniform(0,pi)
        phi = np.random.uniform(0,(2*pi))

        x = np.sin(teta)*np.cos(phi)
        y = np.sin(teta)*np.sin(phi)
        z = np.cos(teta)
        lista.append([round(x,5),round(y,5),round(z,5)])
    return lista

#Parâmetro 

N_rede = 100    #(tamanho da rede)

#Arquivo 

d = rede(N_rede)

with open("dados_4.txt", "w") as arquivo:
    json.dump(d, arquivo)
arquivo.close()

# %%
# Recuperar a aproximação

with open("dados_4.txt", "r") as arquivo:
    d = json.load(arquivo)     # Rede



def calc_dt(k):
    return 1/sum(k)

def K_to_prob(k):
    K_T = sum(k)
    return [k[i]/K_T for i in range(len(k))]

def which_event(p):
    s = [sum(p[:i+1]) for i in range(len(p))]
    u = random.random()
    if u < s[0]:
        return 0
    if u < s[1]:
        return 1
    if u <= s[2]:
        return 2

def calc_kappa2(mu_d, mu_a):
    mu_d = np.array(mu_d)
    mu_a = np.array(mu_a)
    kappa = np.dot(mu_d,mu_a) - 3*(mu_d[0])*(mu_a[0])
    return kappa**2

def calc_K(kappa2,R_0,r,Tau):
    K = ((R_0/r)**6)*kappa2/Tau
    return K
    


#Parâmetros  

N = len(d)     #Tamanho da rede
n = 2          #Número de éxcitons
R_0 = 2
r = 1
Tau = 100



for i in range(n):
    X_0 = 50
    alive = True
    t = 0
    traj = []

    while alive:
        s_i = d[X_0]
        s_E = d[X_0 - 1]
        s_D = d[X_0 + 1]
        kappa2_E = calc_kappa2(s_i,s_E)
        kappa2_D = calc_kappa2(s_i,s_D)

        K_Emi = 1/Tau
        K_Es = calc_K(kappa2_E,R_0,r,Tau)
        K_Dir = calc_K(kappa2_D,R_0,r,Tau)

        list_K = [K_Emi, K_Dir, K_Es]

        P = K_to_prob(list_K) 
        dt = calc_dt(list_K)
        t += dt
        event = which_event(P)

        if event ==0:
            alive = False
        if event == 1:    #Pulo para a direita
            X_0 += 1
            traj.append(X_0)
        if event ==2:     #Pulo para a esquerda 
            X_0 -= 1
            traj.append(X_0)

    print(traj,t)
# Out:
# [49, 50, 49, 50, 49, 50, 49, 50, 49, 50, 51, 50, 49, 50, 49, 50, 49, 48, 47, 48, 49, 50, 51, 52, 53, 54, 53, 54, 55, 54, 53, 54, 55, 54, 55, 54, 55, 54, 55, 54, 53, 54, 53, 54, 55, 56, 57, 56, 57, 58, 59, 58, 59, 58, 59, 58] 88.38578378109771
# [49, 50, 49, 50, 51, 50, 51, 52, 53, 54, 55, 54, 55, 54, 55, 54, 55, 54, 53, 52, 53, 54, 55, 54, 55, 56, 57, 58, 59, 60, 59, 58, 59, 58, 59, 58, 59, 58, 57, 58, 57, 56, 57, 58, 59, 60, 59, 58, 59, 58, 59, 58, 57, 56, 57, 56, 57, 58, 57, 56, 57, 56, 57, 58, 59, 58, 59, 58, 59, 58, 59, 58, 57, 56, 57, 56, 57, 56, 57, 56, 57, 56, 57, 56, 57, 58, 57, 56, 57, 58, 59, 58, 57, 58, 59, 58, 59, 58, 57, 56, 57, 56, 57, 56, 57, 56, 57, 58, 59, 60, 59, 58, 57, 56, 57, 56, 57, 58, 59, 60, 59, 58, 59, 58, 57, 58, 59, 58, 59, 58, 59, 58, 59, 58, 57, 58, 57, 58, 59, 58, 57, 56, 57, 56, 57, 56, 57, 56, 57, 56] 228.31134257135292

# %%
# Recuperar a aproximação

with open("dados_4.txt", "r") as arquivo:
    d = json.load(arquivo)     # Rede


def calc_dt(k):
    return 1/sum(k)

def K_to_prob(k):
    K_T = sum(k)
    return [k[i]/K_T for i in range(len(k))]

def which_event(p):
    s = [sum(p[:i+1]) for i in range(len(p))]
    u = random.random()
    if u < s[0]:
        return 0
    if u < s[1]:
        return 1
    if u <= s[2]:
        return 2

def calc_kappa2(mu_d, mu_a):
    mu_d = np.array(mu_d)
    mu_a = np.array(mu_a)
    kappa = np.dot(mu_d,mu_a) - 3*(mu_d[0])*(mu_a[0])
    return kappa**2

def calc_K(kappa2,R_0,r,Tau):
    K = ((R_0/r)**6)*kappa2/Tau
    return K
    
def cond_contorno(N,X_0):
    if X_0 > N:
        return 0
    if X_0 < 0:
        return N
    return X_0

#Parâmetros  

N = len(d)     #Tamanho da rede
n = 10          #Número de éxcitons
R_0 = 2
r = 1
Tau = 100


for i in range(n):
    X_0 = random.randint(0,N-1)
    alive = True
    t = 0
    traj = []

    while alive:
        s_i = d[X_0]
        s_E = d[cond_contorno(N-1,X_0 -1)]
        s_D = d[cond_contorno(N-1,X_0 +1)]
        kappa2_E = calc_kappa2(s_i,s_E)
        kappa2_D = calc_kappa2(s_i,s_D)
        

        K_Emi = 1/Tau
        K_Es = calc_K(kappa2_E,R_0,r,Tau)
        K_Dir = calc_K(kappa2_D,R_0,r,Tau)

        list_K = [K_Emi, K_Dir, K_Es]

        P = K_to_prob(list_K) 
        dt = calc_dt(list_K)
        t += dt
        event = which_event(P)

        if event ==0:
            alive = False
        if event == 1:    #Pulo para a direita
            X_0 = cond_contorno(N-1,X_0 +1)
            traj.append(X_0)
        if event ==2:     #Pulo para a esquerda 
            X_0 = cond_contorno(N-1,X_0 -1)
            traj.append(X_0)

    print(traj,t)
# Out:
# [31, 30, 31, 32, 31, 32, 31, 30, 31, 30, 31, 32, 31, 30, 31, 30, 31, 32, 31, 30, 31, 30] 64.85418237508054
# [27, 28, 29, 28, 29, 28, 29, 28, 29, 28, 27, 26, 27, 26, 27, 28, 29, 28, 29, 28, 29, 28, 29, 28, 29, 28, 27, 28, 29, 28, 29, 28, 29, 28, 29, 28, 29, 28, 29] 137.86699372737417
# [30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 32, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 32, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 30, 31, 32, 31, 32, 31, 30, 31, 30, 31, 30, 31, 30, 31, 32, 33, 34, 33, 32, 31, 30, 31, 30, 31, 30, 31, 30] 250.9657355249799
# ...

# %%
#Funções

with open("dados_4.txt", "r") as arquivo:
    d = json.load(arquivo)     # Rede

def calc_dt(k):
    return 1/sum(k)

def K_to_prob(k):
    K_T = sum(k)
    return [k[i]/K_T for i in range(len(k))]

def which_event(p):
    s = [sum(p[:i+1]) for i in range(len(p))]
    u = random.random()
    if u < s[0]:
        return 0
    if u < s[1]:
        return 1
    if u <= s[2]:
        return 2

def calc_kappa2(mu_d, mu_a):
    mu_d = np.array(mu_d)
    mu_a = np.array(mu_a)
    kappa = np.dot(mu_d,mu_a) - 3*(mu_d[0])*(mu_a[0])
    return kappa**2

def calc_K(kappa2,R_0,r,Tau):
    K = ((R_0/r)**6)*kappa2/Tau
    return K
    
def cond_contorno(N,X_0):
    if X_0 > N:
        return 0
    if X_0 < 0:
        return N
    return X_0

#Função principal

def traj(d,N,R_0,r,Tau):
    X_0 = random.randint(0,N-1)
    alive = True
    t = 0
    traj = [X_0]

    while alive:
        s_i = d[X_0]
        s_E = d[cond_contorno(N-1,X_0 -1)]
        s_D = d[cond_contorno(N-1,X_0 +1)]
        kappa2_E = calc_kappa2(s_i,s_E)
        kappa2_D = calc_kappa2(s_i,s_D)
        

        K_Emi = 1/Tau
        K_Es = calc_K(kappa2_E,R_0,r,Tau)
        K_Dir = calc_K(kappa2_D,R_0,r,Tau)

        list_K = [K_Emi, K_Dir, K_Es]

        P = K_to_prob(list_K) 
        dt = calc_dt(list_K)
        t += dt
        event = which_event(P)

        if event ==0:
            alive = False
        if event == 1:    #Pulo para a direita
            X_0 = cond_contorno(N-1,X_0 +1)
            traj.append(X_0)
        if event ==2:     #Pulo para a esquerda 
            X_0 = cond_contorno(N-1,X_0 -1)
            traj.append(X_0)

    return(traj,t)


N = len(d)     #Tamanho da rede
n = 2          #Número de éxcitons máximo
R_0 = 2
r = 1
Tau = 100

s = []
for i in range(n):
    trajetoria = traj(d,N,R_0,r,Tau)[0] 
    X_0 = trajetoria[0]
    X_F = trajetoria[-1]
    s.append((X_F - X_0)**2)
L_D = np.sqrt(sum(s)/n)


print(L_D)

#traj = [traj(d,N,R_0,r,Tau) for i in range(n)]
#trajetorias = [traj[i][0] for i in range(n)]
#tempos = [traj[i][1] for i in range(n)]
#print(trajetorias)
#print(len(trajetorias),len(tempos))
#print(tempos)
# Out:
# 2.23606797749979

# %%
#Parâmetros  

N = len(d)     #Tamanho da rede
n = 10          #Número de éxcitons
R_0 = 2
r = 1
Tau = 100

# %%
with open("dados_4.txt", "r") as arquivo:
    d = json.load(arquivo)     # Rede

traj = [traj(d,N,R_0,r,Tau) for i in range(n)]
trajetorias = [traj[i][0] for i in range(n)]
tempos = [traj[i][1] for i in range(n)]
print(trajetorias)
# Out:
# [[1], [67]]
